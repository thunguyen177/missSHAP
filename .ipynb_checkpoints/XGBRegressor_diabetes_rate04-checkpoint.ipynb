# %%
import sklearn
import numpy as np
import pickle as pkl
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
from funcs.utils import *
from funcs.explain import *
import shap
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from funcs.DIMV import DIMVImputation
from funcs.miss_forest import mf

missing_rate = 0.4
nruns = 10
ouput_name = 'XGBRegressor_diabetes_rate04'  

from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target 

def get_split():
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), columns = diabetes.feature_names)
    X_test = pd.DataFrame(scaler.transform(X_test), columns = diabetes.feature_names)
    
    y_train, y_test = y_train.reshape((-1,1)), y_test.reshape((-1,1))
    scaler_y = StandardScaler()
    scaler_y.fit(y_train)
    y_train = pd.DataFrame(scaler_y.transform(y_train))
    y_test = pd.DataFrame(scaler_y.transform(y_test))
    X_train_star = generate_missing_data(X_train, rate=missing_rate)
    X_test_star = generate_missing_data(X_test, rate=missing_rate) 
    return X_train, X_train_star, y_train, X_test, X_test_star, y_test
chosen_model = xgboost.XGBRegressor(n_estimators=100, max_depth=2)
# Out:
# WARNING:tensorflow:From C:\Users\thung\Downloads\all-codes\SHAP missing revision 1 experiments\funcs\GAIN\gain.py:27: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From C:\Users\thung\.conda\envs\mtime\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Generate missing data, impute, and use SHAP to explain

# %%
results = []
for i in range(nruns):
    X_train, X_train_star, y_train, X_test, X_test_star, y_test = get_split()
    print('iteration:',i)
    results.append(one_run(X_train, X_train_star, y_train, X_test, X_test_star, y_test, chosen_model))
# Out:
# iteration: 0
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 19.49it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.64it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.64it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.64it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.80it/s]
# Validation result: best alpha 0.1, best score 0.7695810754825994, scores {0.0: 3.7509287337407553, 0.01: 74.23507028811471, 0.1: 0.7695810754825994, 1.0: 0.8257401603130525, 10.0: 0.954555298449497, 100.0: 1.000069580072812}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 71.93it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.77it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.64it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.69it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Validation result: best alpha 0.1, best score 0.7695810754825992, scores {0.0: 3.7509287337407557, 0.01: 74.2350702881147, 0.1: 0.7695810754825992, 1.0: 0.8257401603130524, 10.0: 0.954555298449497, 100.0: 1.000069580072812}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 249.94it/s]
# loss 0.21469725356488284
# loss 0.0720618522748079
# loss 0.04901667705129568
# loss 0.04871499627434579
# loss 0.05287866142163644
# loss 0.05549262403051869
# loss 0.056960292846052994
# loss 0.05971569479336625
# loss 0.06061926532755304
# loss 0.06188751581291892
# number of runs used by missForest: 10
# loss: 0.06188751581291892
# loss 0.2178334910426104
# loss 0.0682053010930826
# loss 0.05367190689807958
# loss 0.055436785290952535
# loss 0.0553168416807866
# loss 0.054152989868722926
# loss 0.055768499449740154
# loss 0.05830224364356442
# loss 0.059147652284534696
# loss 0.061120913871712305
# number of runs used by missForest: 10
# loss: 0.061120913871712305
# WARNING:tensorflow:From C:\Users\thung\Downloads\all-codes\SHAP missing revision 1 experiments\funcs\GAIN\gain.py:148: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 695.90it/s]
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# iteration: 1
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.07it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.14it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Validation result: best alpha 0.01, best score 0.7405987702052452, scores {0.0: 0.7447975278991994, 0.01: 0.7405987702052452, 0.1: 0.7451411858337412, 1.0: 0.8046566553211584, 10.0: 0.9378461208502169, 100.0: 0.9952571397292963}
# Value alpha used in for transforming is: 0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 72.45it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Validation result: best alpha 0.01, best score 0.7405987702052452, scores {0.0: 0.7447975278991994, 0.01: 0.7405987702052452, 0.1: 0.7451411858337412, 1.0: 0.8046566553211584, 10.0: 0.9378461208502169, 100.0: 0.9952571397292963}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 270.22it/s]
# loss 0.21621717282214684
# loss 0.07438025812995934
# loss 0.0590127485973475
# loss 0.05429854063975964
# loss 0.052915315386159116
# loss 0.05447636496675431
# loss 0.05432191041416694
# loss 0.06141797962536292
# loss 0.06247343760576813
# loss 0.06306752871489907
# number of runs used by missForest: 10
# loss: 0.06306752871489907
# loss 0.20510021977259438
# loss 0.06716784278336009
# loss 0.054978284946719205
# loss 0.05252799255467811
# loss 0.05120421189799013
# loss 0.04903433490383036
# loss 0.050408972830036924
# loss 0.053629963727039924
# loss 0.05733223907005286
# loss 0.05963636876844555
# number of runs used by missForest: 10
# loss: 0.05963636876844555
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 707.39it/s]
# iteration: 2
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 21.88it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.36it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.36it/s]
# Validation result: best alpha 0.1, best score 0.7449311116251032, scores {0.0: 3.4529474574120353, 0.01: 0.8312815368659363, 0.1: 0.7449311116251032, 1.0: 0.8004315529977805, 10.0: 0.9337854924818539, 100.0: 0.9849786162791283}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 72.98it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.30it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.36it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.30it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.25it/s]
# Validation result: best alpha 0.1, best score 0.7449311116251032, scores {0.0: 3.452947457412036, 0.01: 0.8312815368659363, 0.1: 0.7449311116251032, 1.0: 0.8004315529977805, 10.0: 0.9337854924818539, 100.0: 0.9849786162791283}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 256.36it/s]
# loss 0.2085156756107645
# loss 0.08313938218988076
# loss 0.07546065636551653
# loss 0.07324612717890047
# loss 0.07279333401371696
# loss 0.07003201345924825
# loss 0.06341591388064391
# loss 0.06403221018202754
# loss 0.06499762904339497
# loss 0.06561755255586393
# number of runs used by missForest: 10
# loss: 0.06561755255586393
# loss 0.21161416775928055
# loss 0.07785755803576834
# loss 0.06937495771466932
# loss 0.06767987359545834
# loss 0.06261919579209325
# loss 0.06749629370806523
# loss 0.06868609424045756
# loss 0.06883025865116332
# loss 0.06992950960371845
# loss 0.07080581336838951
# number of runs used by missForest: 10
# loss: 0.07080581336838951
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 694.29it/s]
# iteration: 3
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.42it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.63it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.80it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.75it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.86it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Validation result: best alpha 0.1, best score 0.7521897464993142, scores {0.0: 3.2020494687444954, 0.01: 1.0848556081305651, 0.1: 0.7521897464993142, 1.0: 0.8083672631454439, 10.0: 0.9489789280541155, 100.0: 1.0015659997889355}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 75.17it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.69it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.80it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.86it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.69it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.69it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.80it/s]
# Validation result: best alpha 0.1, best score 0.7521897464993142, scores {0.0: 3.2020494687444954, 0.01: 1.0848556081305651, 0.1: 0.7521897464993142, 1.0: 0.8083672631454439, 10.0: 0.9489789280541155, 100.0: 1.0015659997889355}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 263.04it/s]
# loss 0.2045684116142196
# loss 0.07485499346255077
# loss 0.05997245956430296
# loss 0.05628552621035786
# loss 0.05715814548365278
# loss 0.060037081341223965
# loss 0.06187896578777174
# loss 0.06440156432593333
# loss 0.06704681052701932
# loss 0.0665117846872268
# number of runs used by missForest: 10
# loss: 0.0665117846872268
# loss 0.21867324146920583
# loss 0.07511195278846977
# loss 0.06152409045628598
# loss 0.05843994494086838
# loss 0.05822410179712379
# loss 0.0582283571491353
# loss 0.05733117993504969
# loss 0.056335957184367444
# loss 0.05743951665215424
# loss 0.057297084019825806
# number of runs used by missForest: 10
# loss: 0.057297084019825806
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 686.35it/s]
# iteration: 4
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 21.36it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.42it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.32it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.32it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.57it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.57it/s]
# Validation result: best alpha 0.1, best score 0.7559834592274511, scores {0.0: 6.917923686339532, 0.01: 0.9664219937828291, 0.1: 0.7559834592274511, 1.0: 0.8138662085884165, 10.0: 0.9459074475153177, 100.0: 0.9933432194561349}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 69.43it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.42it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.52it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.57it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.62it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.52it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.77it/s]
# Validation result: best alpha 0.1, best score 0.7559834592274511, scores {0.0: 6.917923686339532, 0.01: 0.9664219937828292, 0.1: 0.7559834592274511, 1.0: 0.8138662085884165, 10.0: 0.9459074475153177, 100.0: 0.9933432194561349}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 277.73it/s]
# loss 0.19997239494186902
# loss 0.08650852619806079
# loss 0.06526839514838702
# loss 0.06184889675376753
# loss 0.05963941877414279
# loss 0.0583126463042724
# loss 0.05893310275889704
# loss 0.06054838308730489
# loss 0.06117775765044601
# loss 0.06281718548113396
# number of runs used by missForest: 10
# loss: 0.06281718548113396
# loss 0.20115459765633953
# loss 0.07213082428928745
# loss 0.053853907139331345
# loss 0.050704314212857274
# loss 0.05098109904829744
# loss 0.049974943324348674
# loss 0.053258229893132024
# loss 0.05235404895560829
# loss 0.055247696517498945
# loss 0.057334776057018706
# number of runs used by missForest: 10
# loss: 0.057334776057018706
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 653.45it/s]
# iteration: 5
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.93it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.21it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.75it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.21it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.27it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.86it/s]
# Validation result: best alpha 0.01, best score 0.7516030586356807, scores {0.0: 0.8100915950265528, 0.01: 0.7516030586356807, 0.1: 0.7517735015059447, 1.0: 0.8158111722097049, 10.0: 0.9514937985778954, 100.0: 1.0041974655002512}
# Value alpha used in for transforming is: 0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 75.17it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.15it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.32it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.03it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.98it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.03it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 24.33it/s]
# Validation result: best alpha 0.01, best score 0.7516030586356806, scores {0.0: 0.8100915950265529, 0.01: 0.7516030586356806, 0.1: 0.7517735015059447, 1.0: 0.8158111722097049, 10.0: 0.9514937985778954, 100.0: 1.0041974655002512}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 263.10it/s]
# loss 0.20930375391700398
# loss 0.07849154386666174
# loss 0.06038446179153941
# loss 0.059342985691071624
# loss 0.055872092490474555
# loss 0.05746963834100316
# loss 0.06167399738810397
# loss 0.06565198829896426
# loss 0.07031450749009717
# loss 0.07577493769122323
# number of runs used by missForest: 10
# loss: 0.07577493769122323
# loss 0.21627425253262617
# loss 0.08017372899148824
# loss 0.058891623479443087
# loss 0.061995752654924484
# loss 0.061816465726552604
# loss 0.05995327336070758
# loss 0.05767441186186636
# loss 0.056308193537748144
# loss 0.058382238336019715
# loss 0.0592494808506739
# number of runs used by missForest: 10
# loss: 0.0592494808506739
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 662.10it/s]
# iteration: 6
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.37it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.64it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.36it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.50it/s]
# Validation result: best alpha 0.1, best score 0.7543923341087929, scores {0.0: 3.033191299801124, 0.01: 6.680504055322804, 0.1: 0.7543923341087929, 1.0: 0.813532710013344, 10.0: 0.9541135396187419, 100.0: 1.003788356961533}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 71.92it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.36it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.75it/s]
# Validation result: best alpha 0.1, best score 0.7543923341087929, scores {0.0: 3.033191299801124, 0.01: 6.680504055322804, 0.1: 0.7543923341087929, 1.0: 0.813532710013344, 10.0: 0.9541135396187419, 100.0: 1.003788356961533}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 285.57it/s]
# loss 0.2074623696675851
# loss 0.0710321182515272
# loss 0.052895257123686173
# loss 0.05288766575104084
# loss 0.050122173446104604
# loss 0.050132258562016564
# loss 0.05161760966448778
# loss 0.05282782568116581
# loss 0.050481389183451436
# loss 0.051008116222853096
# number of runs used by missForest: 10
# loss: 0.051008116222853096
# loss 0.2126594181469236
# loss 0.07218197634063353
# loss 0.052506125342556505
# loss 0.04830867581525792
# loss 0.046724320625959145
# loss 0.04770965392400389
# loss 0.047876818644782326
# loss 0.04769348770456195
# loss 0.04858578498638735
# loss 0.050455043548248785
# number of runs used by missForest: 10
# loss: 0.050455043548248785
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 649.21it/s]
# iteration: 7
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.22it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.25it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Validation result: best alpha 0.1, best score 0.7489685032598526, scores {0.0: 1.0722995866245353, 0.01: 0.8355046569690502, 0.1: 0.7489685032598526, 1.0: 0.800644554975193, 10.0: 0.9300576255714144, 100.0: 0.980036177244021}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 74.06it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.64it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.04it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.09it/s]
# Validation result: best alpha 0.1, best score 0.7489685032598526, scores {0.0: 1.0722995866245353, 0.01: 0.8355046569690502, 0.1: 0.7489685032598526, 1.0: 0.800644554975193, 10.0: 0.9300576255714144, 100.0: 0.980036177244021}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 243.86it/s]
# loss 0.19477477637290036
# loss 0.06606260817229725
# loss 0.050505714892382404
# loss 0.047387497632224614
# loss 0.048929242048088725
# loss 0.04753150426694409
# loss 0.04692949884247988
# loss 0.04817239776496176
# loss 0.05031372296498409
# loss 0.05335057863050166
# number of runs used by missForest: 10
# loss: 0.05335057863050166
# loss 0.19983898640981512
# loss 0.06418233480404466
# loss 0.05245354906031739
# loss 0.04793039335751932
# loss 0.04380653674131136
# loss 0.04716990350337804
# loss 0.04830854155779844
# loss 0.05042678377960706
# loss 0.05084714147703649
# loss 0.05439893539328509
# number of runs used by missForest: 10
# loss: 0.05439893539328509
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 654.88it/s]
# iteration: 8
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 21.92it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.36it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.41it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.30it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.25it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.36it/s]
# Validation result: best alpha 0.1, best score 0.7637218417229281, scores {0.0: 3.859504963797159, 0.01: 5.77372965259475, 0.1: 0.7637218417229281, 1.0: 0.8209052126880543, 10.0: 0.950306717578625, 100.0: 0.9962073406820906}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 72.45it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.47it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.63it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.58it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 23.52it/s]
# Validation result: best alpha 0.1, best score 0.7637218417229281, scores {0.0: 3.859504963797159, 0.01: 5.77372965259475, 0.1: 0.7637218417229281, 1.0: 0.8209052126880543, 10.0: 0.950306717578625, 100.0: 0.9962073406820907}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 277.64it/s]
# loss 0.21023570004107187
# loss 0.07196200331318786
# loss 0.05299391269224946
# loss 0.049851639136415715
# loss 0.047869547156733847
# loss 0.04545315139288253
# loss 0.04531181745937324
# loss 0.04668071209051802
# loss 0.04636491736428156
# loss 0.04823054879965057
# number of runs used by missForest: 10
# loss: 0.04823054879965057
# loss 0.21004110187048297
# loss 0.07217051372178175
# loss 0.05727962234115947
# loss 0.057397050611748934
# loss 0.06338252071355618
# loss 0.06555986572145737
# loss 0.06859968226053201
# loss 0.06850443777166652
# loss 0.06472725685637055
# loss 0.06489547989932597
# number of runs used by missForest: 10
# loss: 0.06489547989932597
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 639.53it/s]
# iteration: 9
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 20.79it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.37it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.37it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.93it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 21.23it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.07it/s]
# Validation result: best alpha 0.1, best score 0.7651897234472393, scores {0.0: 6.724771609480574, 0.01: 1.8038859179200668, 0.1: 0.7651897234472393, 1.0: 0.816532644849215, 10.0: 0.9386696478504809, 100.0: 0.9832565105393777}
# Value alpha used in for transforming is: 0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 68.48it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.88it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.83it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.88it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.42it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.83it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 22.88it/s]
# Validation result: best alpha 0.1, best score 0.7651897234472393, scores {0.0: 6.724771609480573, 0.01: 1.8038859179200668, 0.1: 0.7651897234472393, 1.0: 0.816532644849215, 10.0: 0.9386696478504809, 100.0: 0.9832565105393777}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 256.29it/s]
# loss 0.22713603585917758
# loss 0.07680681154121582
# loss 0.06521052738236041
# loss 0.06268762606971608
# loss 0.06349455862001432
# loss 0.06540904632533132
# loss 0.06777567087819007
# loss 0.06713666676963147
# loss 0.06832519690930626
# loss 0.06760441905354037
# number of runs used by missForest: 10
# loss: 0.06760441905354037
# loss 0.23140683476376617
# loss 0.0741104212991502
# loss 0.06000198671296463
# loss 0.05767943013240416
# loss 0.061304132578916884
# loss 0.065972748985577
# loss 0.06751006684359974
# loss 0.07058247656467523
# loss 0.07164205070893366
# loss 0.07015567618565807
# number of runs used by missForest: 10
# loss: 0.07015567618565807
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 636.80it/s]

# %% [markdown]
# So, the first layer of results is the result of each run. Then, for the sub-level:
# - level 0: shape_values_ori, shap_values_xm...
# - level 1:  other_measures = [mse_imputation_all, mse_shap_all, mse_ypred_all, cor_ypred_all, spearman_ypred]

# %%
def get_average_shap_vals(results, j, nruns):
    # get the average shap values from all runs for each imputation method or the original 
    current = results[0][0][j]
    for i in range(1, nruns):
        current.values += results[i][0][j].values
        current.base_values += results[i][0][j].base_values
        current.data += results[i][0][j].data  
    current.values = current.values/nruns
    current.base_values = current.base_values/nruns
    current.data = current.data/nruns
    return current

# %%
shap_values_ori = get_average_shap_vals(results, j = 0, nruns= nruns)
shap_values_xm = get_average_shap_vals(results, j = 1, nruns= nruns)
shap_values_mi = get_average_shap_vals(results, j = 2, nruns = nruns)
shap_values_mice = get_average_shap_vals(results, j = 3, nruns= nruns)
shap_values_dimv = get_average_shap_vals(results, j = 4, nruns= nruns)
shap_values_mf = get_average_shap_vals(results, j = 5, nruns= nruns)
shap_values_soft = get_average_shap_vals(results, j = 6, nruns= nruns)
shap_values_gain = get_average_shap_vals(results, j = 7, nruns= nruns)

# %%
ranking_res = shap_ranking_table(X_train, shap_values_ori,shap_values_xm, shap_values_mi, shap_values_mice,
                   shap_values_dimv, shap_values_mf, shap_values_soft, shap_values_gain)
# Out:
# combined_feature_importance
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & Original & Xgb on missing data & Mean Imputation & MICE & DIMV & missForest & SOFT-IMPUTE & GAIN \\
# Ranking &  &  &  &  &  &  &  &  \\
# \midrule
# s5 & 0.089 & 0.162 & 0.076 & 0.080 & 0.087 & 0.078 & 0.076 & 0.075 \\
# bmi & 0.074 & 0.473 & 0.073 & 0.071 & 0.074 & 0.064 & 0.069 & 0.064 \\
# bp & 0.042 & 0.217 & 0.045 & 0.033 & 0.034 & 0.040 & 0.042 & 0.048 \\
# s6 & 0.033 & 0.110 & 0.038 & 0.040 & 0.038 & 0.035 & 0.027 & 0.039 \\
# s2 & 0.033 & 0.180 & 0.033 & 0.027 & 0.030 & 0.043 & 0.040 & 0.034 \\
# s3 & 0.032 & 0.043 & 0.042 & 0.038 & 0.031 & 0.030 & 0.046 & 0.043 \\
# age & 0.031 & 0.083 & 0.032 & 0.036 & 0.029 & 0.036 & 0.032 & 0.034 \\
# sex & 0.031 & 0.039 & 0.020 & 0.027 & 0.031 & 0.028 & 0.031 & 0.011 \\
# s1 & 0.022 & 0.039 & 0.024 & 0.026 & 0.036 & 0.032 & 0.028 & 0.036 \\
# s4 & 0.018 & 0.038 & 0.039 & 0.026 & 0.024 & 0.037 & 0.035 & 0.046 \\
# \bottomrule
# \end{tabular}

# %%
    j = 0
    mse_now = results[0][1][j]
    for i in range(1, nruns):
        mse_now += results[i][1][j]
    mse_imputation_all = mse_now/nruns  
    print("the MSE between the imputed X_test of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original X_test:")
    print(mse_imputation_all.round(3))

    j = 1
    mse_now = results[0][1][j]
    for i in range(1, nruns):
        mse_now += results[i][1][j]    
    mse_shap_all = mse_now/nruns 
    print("the MSE between the Shapley values of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:")
    print(mse_shap_all.round(3))

    j = 2
    mse_ypred_now = results[0][1][j]
    for i in range(1, nruns):
        mse_ypred_now += results[i][1][j]    
    mse_ypred_all = mse_ypred_now/nruns 
    print("the MSE between y predicted on test set of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:")
    print(mse_ypred_all.round(3))

    j = 3
    mse_ypred_now = results[0][1][j]
    for i in range(1, nruns):
        mse_ypred_now += results[i][1][j]    
    spearman_ypred = mse_ypred_now/nruns 
    print("the ranking correlation for spearman rank correlation between the predicted y on test set of original data and y predicted on imputed data")
    print(spearman_ypred.round(3))

    j = 4
    mse_ypred_now = results[0][1][j]
    for i in range(1, nruns):
        mse_ypred_now += results[i][1][j]    
    spearman_ypred = mse_ypred_now/nruns 
    print("the ranking correlation for spearman rank correlation between imputed features")
    print(spearman_ypred.round(3))
# Out:
# the MSE between the imputed X_test of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original X_test:
# [0.414 0.368 0.257 0.302 0.274 0.484]
# the MSE between the Shapley values of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:
# [0.121 0.029 0.028 0.028 0.031 0.029 0.035]
# the MSE between y predicted on test set of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:
# [0.307 0.312 0.287 0.275 0.347 0.304 0.365]
# the ranking correlation for spearman rank correlation between the predicted y on test set of original data and y predicted on imputed data
# [[0.744 0.   ]
#  [0.741 0.   ]
#  [0.766 0.   ]
#  [0.782 0.   ]
#  [0.727 0.   ]
#  [0.76  0.   ]
#  [0.697 0.   ]]
# the ranking correlation for spearman rank correlation between imputed features
# [[0.404 0.497 0.306 0.38  0.362 0.322 0.457 0.347 0.577 0.398]
#  [0.399 0.539 0.693 0.527 0.095 0.319 0.551 0.39  0.745 0.387]
#  [0.239 0.591 0.666 0.391 0.19  0.349 0.493 0.395 0.79  0.41 ]
#  [0.313 0.546 0.68  0.349 0.259 0.37  0.54  0.354 0.806 0.331]
#  [0.312 0.512 0.642 0.383 0.126 0.35  0.425 0.252 0.751 0.324]
#  [0.331 0.604 0.683 0.462 0.051 0.321 0.589 0.294 0.786 0.296]
#  [0.291   nan 0.604 0.495 0.086 0.241 0.462 0.284 0.632 0.298]]

# %%
dfplot = pd.DataFrame({'MSE':np.hstack((0,mse_imputation_all)), 'Spearman statistic': spearman_ypred[:,0]}, index = ['Xgb on missing data','Mean Imputation','MICE','DIMV','missForest','SOFT-IMPUTE', 'GAIN'])
dfplot
# Out:
#                           MSE  Spearman statistic
# Xgb on missing data  0.000000            0.404479
# Mean Imputation      0.414073            0.398631
# MICE                 0.367724            0.238783
# DIMV                 0.257424            0.313194
# missForest           0.301509            0.311705
# SOFT-IMPUTE          0.273981            0.330713
# GAIN                 0.484084            0.290946

# %%
print('imputation MSE versus Spearman statistic')
plt.figure(figsize=(8, 5))
plt.scatter(dfplot['MSE'], dfplot['Spearman statistic'], color='skyblue')
for i, row in dfplot.iterrows():
    if (row.name == 'Mean Imputation') or (row.name == 'DIMV'):
        plt.text(row['MSE'],row['Spearman statistic'], row.name, ha='left', va='bottom')
    else:
        plt.text(row['MSE'],row['Spearman statistic'], row.name, ha='right', va='bottom') 
plt.ylabel('Spearman statistic')
plt.xlabel('MSE')
plt.xlim(-.2, 0.4)
plt.xticks(rotation=45)
plt.grid(True)  # Adding grid for better visualization
plt.savefig('results/'+ ouput_name+'imputation_mse_spearman'+'.png',bbox_inches='tight')
plt.show()
# Out:
# imputation MSE versus Spearman statistic

# %%
dfplot = pd.DataFrame({'MSE on y test':mse_ypred_all, 'MSE Shap': mse_shap_all}, index = dfplot.index)
dfplot
# Out:
#                      MSE on y test  MSE Shap
# Xgb on missing data       0.307455  0.121347
# Mean Imputation           0.311812  0.029344
# MICE                      0.286986  0.028262
# DIMV                      0.275161  0.028372
# missForest                0.346833  0.030981
# SOFT-IMPUTE               0.303779  0.029217
# GAIN                      0.364989  0.034975

# %%
print('imputation MSE versus Shapley MSE')
plt.figure(figsize=(8, 5))
plt.scatter(dfplot['MSE on y test'],dfplot['MSE Shap'], color='skyblue')
for i, row in dfplot.iterrows():
    plt.text(row['MSE on y test'],row['MSE Shap'], row.name, ha='center', va='bottom')
plt.ylabel('MSE Shap')
plt.xlabel('MSE on y test')
plt.xlim(0.16, 0.29)
plt.xticks(rotation=45)
plt.grid(True)  # Adding grid for better visualization
plt.savefig('results/'+ ouput_name+'imputation_mse_vs_shap_mse'+'.png',bbox_inches='tight')
plt.show()
# Out:
# imputation MSE versus Shapley MSE

# %%
dfplot = pd.DataFrame({'MSE':np.hstack((0,mse_imputation_all)), 'MSE Shap': mse_shap_all}, index = dfplot.index)
dfplot
# Out:
#                           MSE  MSE Shap
# Xgb on missing data  0.000000  0.121347
# Mean Imputation      0.414073  0.029344
# MICE                 0.367724  0.028262
# DIMV                 0.257424  0.028372
# missForest           0.301509  0.030981
# SOFT-IMPUTE          0.273981  0.029217
# GAIN                 0.484084  0.034975

# %%
print('imputation MSE versus Shapley MSE')
plt.figure(figsize=(8, 5))
plt.scatter(dfplot['MSE'],dfplot['MSE Shap'], color='skyblue')
for i, row in dfplot.iterrows():
    if (row.name == 'missForest') or (row.name == 'MICE'):
        plt.text(row['MSE'],row['MSE Shap'], row.name, ha='left', va='top')
    else:
        if  (row.name == 'DIMV'):
            plt.text(row['MSE'],row['MSE Shap'], row.name, ha='right', va='top')
        else:
            plt.text(row['MSE'],row['MSE Shap'], row.name, ha='right', va='bottom')     
plt.ylabel('MSE Shap')
plt.xlabel('MSE')
plt.xlim(-0.1, 0.25)
plt.xticks(rotation=45)
plt.grid(True)  # Adding grid for better visualization
plt.savefig('results/'+ ouput_name+'imputation_mse_vs_shap_mse'+'.png',bbox_inches='tight')
plt.show()
# Out:
# imputation MSE versus Shapley MSE

# %%
plt.figure()
shap.plots.beeswarm(shap_values_ori, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'ori'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_xm, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'xm'+'.png',bbox_inches='tight')
plt.show()
# Out:
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\numpy\lib\nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(

# %%
plt.figure()
shap.plots.beeswarm(shap_values_mi, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'mi'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_mice, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'mice'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_dimv, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'dimv'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_mf, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'mf'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_soft, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'soft'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_gain, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'gain'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.bar(shap_values_ori, show=False)
plt.savefig('results/'+ouput_name+'bar_ori'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_xm, show=False)
plt.savefig('results/'+ouput_name+'bar_xm'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_mi, show=False)
plt.savefig('results/'+ouput_name+'bar_mi'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_mice, show=False)
plt.savefig('results/'+ouput_name+'bar_mice'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_dimv, show=False)
plt.savefig('results/'+ouput_name+'bar_dimv'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_mf, show=False)
plt.savefig('results/'+ouput_name+'bar_mf'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_soft, show=False)
plt.savefig('results/'+ouput_name+'bar_soft'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_gain, show=False)
plt.savefig('results/'+ouput_name+'bar_gain'+'.png',bbox_inches='tight')

# %%
plt.figure(dpi=1000)
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(200,100))
plt.sca(axes[0,0])
shap.plots.bar(shap_values_ori, show=False)
plt.sca(axes[0,1])
shap.plots.bar(shap_values_xm, show=False)
plt.sca(axes[0,2])
shap.plots.bar(shap_values_mi, show=False)
plt.sca(axes[1,0])
shap.plots.bar(shap_values_mice, show=False)
plt.sca(axes[1,1])
shap.plots.bar(shap_values_dimv, show=False)
plt.sca(axes[1,2])
shap.plots.bar(shap_values_mf, show=False)
plt.sca(axes[1,3])
shap.plots.bar(shap_values_soft, show=False)
axes[0,3].set_visible(False)
axes[0,0].set_xlabel('')
axes[0,1].set_xlim(0,0.3)
axes[1,1].set_xlabel('')
axes[0,2].set_xlabel('')
axes[1,0].set_xlabel('')
axes[1,3].set_xlabel('')
axes[0,1].set_ylabel('')
axes[0,2].set_ylabel('')
axes[1,1].set_ylabel('')
plt.subplots_adjust(wspace=3.9, hspace = .5) 
plt.savefig('results/'+ouput_name+'bar'+'.png',bbox_inches='tight')
plt.show()

# %%
column_mean_ori = np.mean(shap_values_ori.values, axis=0)
column_mean_xm = np.mean(shap_values_xm.values, axis=0)
column_mean_mi = np.mean(shap_values_mi.values, axis=0)
column_mean_mice = np.mean(shap_values_mice.values, axis=0)
column_mean_dimv = np.mean(shap_values_dimv.values, axis=0)
column_mean_mf = np.mean(shap_values_mf.values, axis=0)
column_mean_soft = np.mean(shap_values_soft.values, axis=0)
heat_df = pd.DataFrame(np.vstack((column_mean_ori, column_mean_xm,column_mean_mi,column_mean_mice,
                                  column_mean_dimv,column_mean_mf,column_mean_soft)))
heat_df.columns = X_train.columns
heat_df.index = np.array(['original', 'XgbM', 'mean imputation', 'MICE','DIMV','missForest', 'SOFT-IMPUTE'])
plt.figure(figsize=(10, 6))
sns.heatmap(heat_df, cmap='viridis', annot=True, cbar=False)
plt.title('Heatmap of shapley average feature mean')
plt.xlabel('Feature')
plt.ylabel('imputation method')
plt.savefig('results/'+ouput_name+'heatmap'+'.png',bbox_inches='tight')
plt.show()
