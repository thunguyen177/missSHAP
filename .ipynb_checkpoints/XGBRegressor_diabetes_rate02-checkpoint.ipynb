# %%
import sklearn
import numpy as np
import pickle as pkl
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
from funcs.utils import *
from funcs.explain import *
import shap
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from funcs.DIMV import DIMVImputation
from funcs.miss_forest import mf

missing_rate = 0.2
nruns = 10
ouput_name = 'XGBRegressor_diabetes_rate02'  

from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target 

def get_split():
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), columns = diabetes.feature_names)
    X_test = pd.DataFrame(scaler.transform(X_test), columns = diabetes.feature_names)
    
    y_train, y_test = y_train.reshape((-1,1)), y_test.reshape((-1,1))
    scaler_y = StandardScaler()
    scaler_y.fit(y_train)
    y_train = pd.DataFrame(scaler_y.transform(y_train))
    y_test = pd.DataFrame(scaler_y.transform(y_test))
    X_train_star = generate_missing_data(X_train, rate=missing_rate)
    X_test_star = generate_missing_data(X_test, rate=missing_rate) 
    return X_train, X_train_star, y_train, X_test, X_test_star, y_test
chosen_model = xgboost.XGBRegressor(n_estimators=100, max_depth=2)
# Out:
# WARNING:tensorflow:From C:\Users\thung\Downloads\all-codes\SHAP missing revision 1 experiments\funcs\GAIN\gain.py:27: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From C:\Users\thung\.conda\envs\mtime\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Generate missing data, impute, and use SHAP to explain

# %%
results = []
for i in range(nruns):
    X_train, X_train_star, y_train, X_test, X_test_star, y_test = get_split()
    print('iteration:',i)
    results.append(one_run(X_train, X_train_star, y_train, X_test, X_test_star, y_test, chosen_model))
# Out:
# iteration: 0
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 40.48it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.25it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.99it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.49it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.74it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.74it/s]
# Validation result: best alpha 0.1, best score 0.7037518037230198, scores {0.0: 0.7878166359408013, 0.01: 0.709764599608171, 0.1: 0.7037518037230198, 1.0: 0.7834038017544758, 10.0: 0.933589363244878, 100.0: 0.9947194798494073}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 212.72it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.24it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 50.24it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.99it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.77it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.74it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.49it/s]
# Validation result: best alpha 0.1, best score 0.7037518037230198, scores {0.0: 0.7878166359408013, 0.01: 0.709764599608171, 0.1: 0.7037518037230198, 1.0: 0.7834038017544758, 10.0: 0.933589363244878, 100.0: 0.9947194798494075}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 588.16it/s]
# loss 0.09889631162015981
# loss 0.014198914062511022
# loss 0.00798629015138611
# number of runs used by missForest: 3
# loss: 0.00798629015138611
# loss 0.10035942904561701
# loss 0.014547190337853002
# loss 0.007556675639421933
# number of runs used by missForest: 3
# loss: 0.007556675639421933
# WARNING:tensorflow:From C:\Users\thung\Downloads\all-codes\SHAP missing revision 1 experiments\funcs\GAIN\gain.py:148: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 700.78it/s]
# iteration: 1
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 41.83it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.94it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.16it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.16it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Validation result: best alpha 0.1, best score 0.7053313464834646, scores {0.0: 0.9935127495830564, 0.01: 2.267318321510603, 0.1: 0.7053313464834646, 1.0: 0.786623593741617, 10.0: 0.9371262239127359, 100.0: 0.9988509544813927}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 204.04it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.16it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.04it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.16it/s]
# Validation result: best alpha 0.1, best score 0.7053313464834646, scores {0.0: 0.9935127495830564, 0.01: 2.267318321510603, 0.1: 0.7053313464834646, 1.0: 0.7866235937416169, 10.0: 0.937126223912736, 100.0: 0.9988509544813928}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 526.26it/s]
# loss 0.106953078070066
# loss 0.0178864947881811
# loss 0.009464645377983083
# number of runs used by missForest: 3
# loss: 0.009464645377983083
# loss 0.1066441039491441
# loss 0.017390759360996953
# loss 0.009036208533045258
# number of runs used by missForest: 3
# loss: 0.009036208533045258
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 720.99it/s]
# iteration: 2
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 40.97it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.84it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.61it/s]
# Validation result: best alpha 0.01, best score 0.6861907107003156, scores {0.0: 0.702263484881343, 0.01: 0.6861907107003156, 0.1: 0.6940407888876206, 1.0: 0.7717901674983892, 10.0: 0.920852578484987, 100.0: 0.9824487133854981}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 212.72it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.61it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.61it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.61it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.07it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.07it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.84it/s]
# Validation result: best alpha 0.01, best score 0.6861907107003156, scores {0.0: 0.702263484881343, 0.01: 0.6861907107003156, 0.1: 0.6940407888876206, 1.0: 0.7717901674983892, 10.0: 0.920852578484987, 100.0: 0.9824487133854981}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 624.87it/s]
# loss 0.11071719013308767
# loss 0.016155756878258876
# loss 0.0104134669418535
# loss 0.010863053045820747
# loss 0.011423735512921146
# loss 0.012495438836451132
# loss 0.013153018271682517
# loss 0.013819549117254028
# loss 0.014017767504378267
# loss 0.01414970275907623
# number of runs used by missForest: 10
# loss: 0.01414970275907623
# loss 0.10686640357257762
# loss 0.014899109283435257
# loss 0.007618712362220994
# number of runs used by missForest: 3
# loss: 0.007618712362220994
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 699.14it/s]
# iteration: 3
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 43.47it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.25it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.49it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.53it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.01it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.01it/s]
# Validation result: best alpha 0.01, best score 0.670482559676391, scores {0.0: 0.6728990527807382, 0.01: 0.670482559676391, 0.1: 0.6819139951874679, 1.0: 0.760797846590366, 10.0: 0.9237275664633804, 100.0: 0.9916061620268882}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 227.23it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.01it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.25it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.49it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.49it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.25it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 49.25it/s]
# Validation result: best alpha 0.01, best score 0.670482559676391, scores {0.0: 0.6728990527807384, 0.01: 0.670482559676391, 0.1: 0.6819139951874679, 1.0: 0.760797846590366, 10.0: 0.9237275664633804, 100.0: 0.9916061620268882}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 499.92it/s]
# loss 0.09747764027885239
# loss 0.013902598259550047
# loss 0.010035955260889871
# loss 0.008404176789599326
# number of runs used by missForest: 4
# loss: 0.008404176789599326
# loss 0.10078548414208034
# loss 0.014747417218357137
# loss 0.009462623063131
# number of runs used by missForest: 3
# loss: 0.009462623063131
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 687.92it/s]
# iteration: 4
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 42.18it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.30it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.07it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.84it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.30it/s]
# Validation result: best alpha 0.1, best score 0.6838284909566118, scores {0.0: 0.728403686926222, 0.01: 0.7031470019563396, 0.1: 0.6838284909566118, 1.0: 0.7634539198593197, 10.0: 0.9230599745222264, 100.0: 0.9886948959923628}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 208.29it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.84it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.61it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.30it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 48.07it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.84it/s]
# Validation result: best alpha 0.1, best score 0.6838284909566117, scores {0.0: 0.7284036869262219, 0.01: 0.7031470019563396, 0.1: 0.6838284909566117, 1.0: 0.7634539198593197, 10.0: 0.9230599745222264, 100.0: 0.9886948959923629}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 555.41it/s]
# loss 0.1014305633594679
# loss 0.017866131145048723
# loss 0.011232766558237215
# loss 0.008426986133700977
# number of runs used by missForest: 4
# loss: 0.008426986133700977
# loss 0.10825498786170432
# loss 0.018788053721940368
# loss 0.010151023066028443
# loss 0.007858543740635136
# number of runs used by missForest: 4
# loss: 0.007858543740635136
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 689.43it/s]
# iteration: 5
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 40.81it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Validation result: best alpha 0.1, best score 0.7054592825950861, scores {0.0: 14.755938398821042, 0.01: 0.8062079573607147, 0.1: 0.7054592825950861, 1.0: 0.7773586708833583, 10.0: 0.9305503342811163, 100.0: 0.9914498234457767}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 204.04it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.04it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 41.14it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 44.04it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Validation result: best alpha 0.1, best score 0.7054592825950861, scores {0.0: 14.755938398821042, 0.01: 0.8062079573607148, 0.1: 0.7054592825950861, 1.0: 0.7773586708833583, 10.0: 0.9305503342811163, 100.0: 0.9914498234457767}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 666.57it/s]
# loss 0.09825018268012994
# loss 0.017030714821389757
# loss 0.01129529937548132
# loss 0.010217013584922526
# loss 0.01092216577704556
# loss 0.011735039539147138
# loss 0.0127357636198677
# loss 0.014112957445546855
# loss 0.014702084507809292
# loss 0.014613605076840501
# number of runs used by missForest: 10
# loss: 0.014613605076840501
# loss 0.10339724229353732
# loss 0.01984348086431218
# loss 0.013544321219973109
# loss 0.013206087535864183
# loss 0.012925370444783348
# loss 0.013105087797119469
# loss 0.013507696552667963
# loss 0.014363462982667486
# loss 0.015181614023511817
# loss 0.016042123992046936
# number of runs used by missForest: 10
# loss: 0.016042123992046936
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 666.52it/s]
# iteration: 6
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 41.66it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Validation result: best alpha 0.01, best score 0.6761247223584375, scores {0.0: 0.6889713319594324, 0.01: 0.6761247223584375, 0.1: 0.6852369884307762, 1.0: 0.770694217142202, 10.0: 0.9345680530199236, 100.0: 0.9998386851408656}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 212.72it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.72it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.94it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 47.38it/s]
# Validation result: best alpha 0.01, best score 0.6761247223584375, scores {0.0: 0.6889713319594324, 0.01: 0.6761247223584375, 0.1: 0.6852369884307762, 1.0: 0.770694217142202, 10.0: 0.9345680530199235, 100.0: 0.9998386851408656}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 476.10it/s]
# loss 0.08818455255570075
# loss 0.01375113812076001
# loss 0.008648015007260836
# number of runs used by missForest: 3
# loss: 0.008648015007260836
# loss 0.09562673505334934
# loss 0.014080049495732695
# loss 0.009385989578107504
# number of runs used by missForest: 3
# loss: 0.009385989578107504
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 659.19it/s]
# iteration: 7
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 41.31it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.04it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.44it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Validation result: best alpha 0.01, best score 0.7092756088360247, scores {0.0: 0.7115189839145288, 0.01: 0.7092756088360247, 0.1: 0.7147344033203723, 1.0: 0.7829678611911454, 10.0: 0.9255182065059416, 100.0: 0.9850906437195881}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 204.04it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.24it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Validation result: best alpha 0.01, best score 0.7092756088360247, scores {0.0: 0.7115189839145288, 0.01: 0.7092756088360247, 0.1: 0.7147344033203723, 1.0: 0.7829678611911454, 10.0: 0.9255182065059416, 100.0: 0.9850906437195881}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 666.53it/s]
# loss 0.11406388979400077
# loss 0.01908922647361617
# loss 0.011951536036678796
# loss 0.009249812564411148
# number of runs used by missForest: 4
# loss: 0.009249812564411148
# loss 0.10972224707280188
# loss 0.017018190622629863
# loss 0.010280164982268653
# loss 0.008800305091260728
# number of runs used by missForest: 4
# loss: 0.008800305091260728
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 652.03it/s]
# iteration: 8
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 40.64it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.44it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.44it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Validation result: best alpha 0.1, best score 0.684053892205749, scores {0.0: 0.8038738853836734, 0.01: 1.2574060806362906, 0.1: 0.684053892205749, 1.0: 0.7726467300412326, 10.0: 0.9351534737156956, 100.0: 0.9973712350371707}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 208.29it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 44.83it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.44it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.86it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Validation result: best alpha 0.1, best score 0.684053892205749, scores {0.0: 0.8038738853836734, 0.01: 1.2574060806362906, 0.1: 0.684053892205749, 1.0: 0.7726467300412326, 10.0: 0.9351534737156955, 100.0: 0.9973712350371707}
# Value alpha used in for transforming is: 0.1
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 769.09it/s]
# loss 0.10325757496787974
# loss 0.020066467073090885
# loss 0.012620557799312968
# loss 0.010924957874785946
# loss 0.012944782310953265
# loss 0.015457066326712192
# loss 0.017423453251251646
# loss 0.018534363593325963
# loss 0.019197234616852545
# loss 0.021099977714977472
# number of runs used by missForest: 10
# loss: 0.021099977714977472
# loss 0.10434996228510579
# loss 0.018796703579501955
# loss 0.012852166022087762
# loss 0.01311317593585485
# loss 0.014434632610474092
# loss 0.015746975405513213
# loss 0.015881572637424134
# loss 0.016600272107995678
# loss 0.016851302144042027
# loss 0.017649249421311453
# number of runs used by missForest: 10
# loss: 0.017649249421311453
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 640.88it/s]
# iteration: 9
# C:\Users\thung\.conda\envs\mtime\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 40.15it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Validation result: best alpha 0.01, best score 0.6947000164807037, scores {0.0: 0.6960479442849974, 0.01: 0.6947000164807037, 0.1: 0.7051858261043384, 1.0: 0.7803387260812271, 10.0: 0.9316179463066233, 100.0: 0.9949494147902883}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 204.04it/s]
# Start Cross Validation with alphas = [0.0, 0.01, 0.1, 1.0, 10.0, 100.0] and 100.0 % of training set
# Running Cross Validation, alpha=0.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 45.65it/s]
# Running Cross Validation, alpha=0.01
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.07it/s]
# Running Cross Validation, alpha=0.1
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=1.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Running Cross Validation, alpha=100.0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 46.29it/s]
# Validation result: best alpha 0.01, best score 0.6947000164807037, scores {0.0: 0.6960479442849974, 0.01: 0.6947000164807037, 0.1: 0.7051858261043384, 1.0: 0.7803387260812271, 10.0: 0.9316179463066233, 100.0: 0.9949494147902883}
# Value alpha used in for transforming is: 0.01
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 666.55it/s]
# loss 0.09553654550971358
# loss 0.018304165735692973
# loss 0.009950201962977438
# number of runs used by missForest: 3
# loss: 0.009950201962977438
# loss 0.09353700592316648
# loss 0.016197482016841708
# loss 0.009327218557496048
# number of runs used by missForest: 3
# loss: 0.009327218557496048
# 100%|███████████████████████████████████████████████████████████████████████████████| 300/300 [00:00<00:00, 626.17it/s]

# %% [markdown]
# So, the first layer of results is the result of each run. Then, for the sub-level:
# - level 0: shape_values_ori, shap_values_xm...
# - level 1:  other_measures = [mse_imputation_all, mse_shap_all, mse_ypred_all, cor_ypred_all, spearman_ypred]

# %%
def get_average_shap_vals(results, j, nruns):
    # get the average shap values from all runs for each imputation method or the original 
    current = results[0][0][j]
    for i in range(1, nruns):
        current.values += results[i][0][j].values
        current.base_values += results[i][0][j].base_values
        current.data += results[i][0][j].data  
    current.values = current.values/nruns
    current.base_values = current.base_values/nruns
    current.data = current.data/nruns
    return current

# %%
shap_values_ori = get_average_shap_vals(results, j = 0, nruns= nruns)
shap_values_xm = get_average_shap_vals(results, j = 1, nruns= nruns)
shap_values_mi = get_average_shap_vals(results, j = 2, nruns = nruns)
shap_values_mice = get_average_shap_vals(results, j = 3, nruns= nruns)
shap_values_dimv = get_average_shap_vals(results, j = 4, nruns= nruns)
shap_values_mf = get_average_shap_vals(results, j = 5, nruns= nruns)
shap_values_soft = get_average_shap_vals(results, j = 6, nruns= nruns)
shap_values_gain = get_average_shap_vals(results, j = 7, nruns= nruns)

# %%
ranking_res = shap_ranking_table(X_train, shap_values_ori,shap_values_xm, shap_values_mi, shap_values_mice,
                   shap_values_dimv, shap_values_mf, shap_values_soft, shap_values_gain)
# Out:
# combined_feature_importance
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & Original & Xgb on missing data & Mean Imputation & MICE & DIMV & missForest & SOFT-IMPUTE & GAIN \\
# Ranking &  &  &  &  &  &  &  &  \\
# \midrule
# s5 & 0.103 & 0.114 & 0.084 & 0.094 & 0.104 & 0.090 & 0.095 & 0.086 \\
# bmi & 0.072 & 0.259 & 0.077 & 0.076 & 0.076 & 0.081 & 0.080 & 0.077 \\
# bp & 0.050 & 0.166 & 0.060 & 0.047 & 0.045 & 0.048 & 0.049 & 0.053 \\
# age & 0.040 & 0.065 & 0.036 & 0.039 & 0.036 & 0.034 & 0.041 & 0.038 \\
# s6 & 0.036 & 0.072 & 0.039 & 0.039 & 0.036 & 0.038 & 0.033 & 0.044 \\
# s3 & 0.034 & 0.035 & 0.043 & 0.042 & 0.042 & 0.037 & 0.042 & 0.043 \\
# s2 & 0.030 & 0.062 & 0.031 & 0.021 & 0.027 & 0.037 & 0.025 & 0.033 \\
# sex & 0.027 & 0.026 & 0.024 & 0.033 & 0.033 & 0.032 & 0.028 & 0.025 \\
# s1 & 0.020 & 0.032 & 0.024 & 0.024 & 0.028 & 0.026 & 0.024 & 0.024 \\
# s4 & 0.016 & 0.024 & 0.021 & 0.020 & 0.018 & 0.016 & 0.016 & 0.021 \\
# \bottomrule
# \end{tabular}

# %%
    j = 0
    mse_now = results[0][1][j]
    for i in range(1, nruns):
        mse_now += results[i][1][j]
    mse_imputation_all = mse_now/nruns  
    print("the MSE between the imputed X_test of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original X_test:")
    print(mse_imputation_all.round(3))

    j = 1
    mse_now = results[0][1][j]
    for i in range(1, nruns):
        mse_now += results[i][1][j]    
    mse_shap_all = mse_now/nruns 
    print("the MSE between the Shapley values of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:")
    print(mse_shap_all.round(3))

    j = 2
    mse_ypred_now = results[0][1][j]
    for i in range(1, nruns):
        mse_ypred_now += results[i][1][j]    
    mse_ypred_all = mse_ypred_now/nruns 
    print("the MSE between y predicted on test set of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:")
    print(mse_ypred_all.round(3))

    j = 3
    mse_ypred_now = results[0][1][j]
    for i in range(1, nruns):
        mse_ypred_now += results[i][1][j]    
    spearman_ypred = mse_ypred_now/nruns 
    print("the ranking correlation for spearman rank correlation between the predicted y on test set of original data and y predicted on imputed data")
    print(spearman_ypred.round(3))

    j = 4
    mse_ypred_now = results[0][1][j]
    for i in range(1, nruns):
        mse_ypred_now += results[i][1][j]    
    spearman_ypred = mse_ypred_now/nruns 
    print("the ranking correlation for spearman rank correlation between imputed features")
    print(spearman_ypred.round(3))
# Out:
# the MSE between the imputed X_test of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original X_test:
# [0.208 0.106 0.106 0.119 0.112 0.236]
# the MSE between the Shapley values of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:
# [0.067 0.018 0.015 0.015 0.018 0.015 0.021]
# the MSE between y predicted on test set of mean imputation, MICE, DIMV, MissForest, SOFT-IMPUTE and the original:
# [0.174 0.171 0.148 0.156 0.167 0.163 0.199]
# the ranking correlation for spearman rank correlation between the predicted y on test set of original data and y predicted on imputed data
# [[0.853 0.   ]
#  [0.857 0.   ]
#  [0.875 0.   ]
#  [0.867 0.   ]
#  [0.863 0.   ]
#  [0.868 0.   ]
#  [0.832 0.   ]]
# the ranking correlation for spearman rank correlation between imputed features
# [[ 0.618  0.728  0.586  0.572  0.562  0.65   0.706  0.549  0.82   0.661]
#  [ 0.606  0.777  0.797  0.687  0.152  0.331  0.704  0.217  0.835  0.656]
#  [ 0.567  0.796  0.773  0.704  0.436  0.428  0.759  0.234  0.904  0.595]
#  [ 0.576  0.797  0.792  0.692  0.358  0.426  0.775  0.178  0.905  0.581]
#  [ 0.55   0.779  0.783  0.688 -0.009  0.391  0.781  0.064  0.896  0.557]
#  [ 0.55   0.795  0.79   0.682  0.344  0.463  0.771  0.231  0.895  0.578]
#  [ 0.493  0.776  0.731  0.687  0.164  0.278  0.656  0.127  0.822  0.569]]

# %%
dfplot = pd.DataFrame({'MSE':np.hstack((0,mse_imputation_all)), 'Spearman statistic': spearman_ypred[:,0]}, index = ['Xgb on missing data','Mean Imputation','MICE','DIMV','missForest','SOFT-IMPUTE', 'GAIN'])
dfplot
# Out:
#                           MSE  Spearman statistic
# Xgb on missing data  0.000000            0.617877
# Mean Imputation      0.207848            0.605919
# MICE                 0.105513            0.566519
# DIMV                 0.106036            0.576011
# missForest           0.119062            0.550317
# SOFT-IMPUTE          0.112401            0.550230
# GAIN                 0.235682            0.493141

# %%
print('imputation MSE versus Spearman statistic')
plt.figure(figsize=(8, 5))
plt.scatter(dfplot['MSE'], dfplot['Spearman statistic'], color='skyblue')
for i, row in dfplot.iterrows():
    if (row.name == 'Mean Imputation') or (row.name == 'DIMV'):
        plt.text(row['MSE'],row['Spearman statistic'], row.name, ha='left', va='bottom')
    else:
        plt.text(row['MSE'],row['Spearman statistic'], row.name, ha='right', va='bottom') 
plt.ylabel('Spearman statistic')
plt.xlabel('MSE')
plt.xlim(-.2, 0.4)
plt.xticks(rotation=45)
plt.grid(True)  # Adding grid for better visualization
plt.savefig('results/'+ ouput_name+'imputation_mse_spearman'+'.png',bbox_inches='tight')
plt.show()
# Out:
# imputation MSE versus Spearman statistic

# %%
dfplot = pd.DataFrame({'MSE on y test':mse_ypred_all, 'MSE Shap': mse_shap_all}, index = dfplot.index)
dfplot
# Out:
#                      MSE on y test  MSE Shap
# Xgb on missing data       0.173647  0.067287
# Mean Imputation           0.171383  0.018488
# MICE                      0.147907  0.014653
# DIMV                      0.155506  0.015474
# missForest                0.167332  0.017676
# SOFT-IMPUTE               0.162938  0.015050
# GAIN                      0.198676  0.021232

# %%
print('imputation MSE versus Shapley MSE')
plt.figure(figsize=(8, 5))
plt.scatter(dfplot['MSE on y test'],dfplot['MSE Shap'], color='skyblue')
for i, row in dfplot.iterrows():
    plt.text(row['MSE on y test'],row['MSE Shap'], row.name, ha='center', va='bottom')
plt.ylabel('MSE Shap')
plt.xlabel('MSE on y test')
plt.xlim(0.16, 0.29)
plt.xticks(rotation=45)
plt.grid(True)  # Adding grid for better visualization
plt.savefig('results/'+ ouput_name+'imputation_mse_vs_shap_mse'+'.png',bbox_inches='tight')
plt.show()
# Out:
# imputation MSE versus Shapley MSE

# %%
dfplot = pd.DataFrame({'MSE':np.hstack((0,mse_imputation_all)), 'MSE Shap': mse_shap_all}, index = dfplot.index)
dfplot
# Out:
#                           MSE  MSE Shap
# Xgb on missing data  0.000000  0.067287
# Mean Imputation      0.207848  0.018488
# MICE                 0.105513  0.014653
# DIMV                 0.106036  0.015474
# missForest           0.119062  0.017676
# SOFT-IMPUTE          0.112401  0.015050
# GAIN                 0.235682  0.021232

# %%
print('imputation MSE versus Shapley MSE')
plt.figure(figsize=(8, 5))
plt.scatter(dfplot['MSE'],dfplot['MSE Shap'], color='skyblue')
for i, row in dfplot.iterrows():
    if (row.name == 'missForest') or (row.name == 'MICE'):
        plt.text(row['MSE'],row['MSE Shap'], row.name, ha='left', va='top')
    else:
        if  (row.name == 'DIMV'):
            plt.text(row['MSE'],row['MSE Shap'], row.name, ha='right', va='top')
        else:
            plt.text(row['MSE'],row['MSE Shap'], row.name, ha='right', va='bottom')     
plt.ylabel('MSE Shap')
plt.xlabel('MSE')
plt.xlim(-0.1, 0.25)
plt.xticks(rotation=45)
plt.grid(True)  # Adding grid for better visualization
plt.savefig('results/'+ ouput_name+'imputation_mse_vs_shap_mse'+'.png',bbox_inches='tight')
plt.show()
# Out:
# imputation MSE versus Shapley MSE

# %%
plt.figure()
shap.plots.beeswarm(shap_values_ori, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'ori'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_xm, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'xm'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_mi, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'mi'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_mice, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'mice'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_dimv, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'dimv'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_mf, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'mf'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_soft, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'soft'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.beeswarm(shap_values_soft, max_display=10, show=False)
plt.savefig('results/'+ ouput_name+'beeswarm'+'gain'+'.png',bbox_inches='tight')
plt.show()

# %%
plt.figure()
shap.plots.bar(shap_values_ori, show=False)
plt.savefig('results/'+ouput_name+'bar_ori'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_xm, show=False)
plt.savefig('results/'+ouput_name+'bar_xm'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_mi, show=False)
plt.savefig('results/'+ouput_name+'bar_mi'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_mice, show=False)
plt.savefig('results/'+ouput_name+'bar_mice'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_dimv, show=False)
plt.savefig('results/'+ouput_name+'bar_dimv'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_mf, show=False)
plt.savefig('results/'+ouput_name+'bar_mf'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_soft, show=False)
plt.savefig('results/'+ouput_name+'bar_soft'+'.png',bbox_inches='tight')

plt.figure()
shap.plots.bar(shap_values_gain, show=False)
plt.savefig('results/'+ouput_name+'bar_gain'+'.png',bbox_inches='tight')

# %%
plt.figure(dpi=1000)
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(200,100))
plt.sca(axes[0,0])
shap.plots.bar(shap_values_ori, show=False)
plt.sca(axes[0,1])
shap.plots.bar(shap_values_xm, show=False)
plt.sca(axes[0,2])
shap.plots.bar(shap_values_mi, show=False)
plt.sca(axes[0,3])
shap.plots.bar(shap_values_mice, show=False)
plt.sca(axes[1,0])
shap.plots.bar(shap_values_dimv, show=False)
plt.sca(axes[1,1])
shap.plots.bar(shap_values_mf, show=False)
plt.sca(axes[1,2])
shap.plots.bar(shap_values_soft, show=False)
plt.sca(axes[1,3])
shap.plots.bar(shap_values_gain, show=False)
axes[0,3].set_visible(False)
axes[0,0].set_xlabel('')
axes[0,1].set_xlim(0,0.3)
axes[1,1].set_xlabel('')
axes[0,2].set_xlabel('')
axes[1,0].set_xlabel('')
axes[1,3].set_xlabel('')
axes[0,1].set_ylabel('')
axes[0,2].set_ylabel('')
axes[1,1].set_ylabel('')
plt.subplots_adjust(wspace=3.9, hspace = .5) 
plt.savefig('results/'+ouput_name+'bar'+'.png',bbox_inches='tight')
plt.show()

# %%
column_mean_ori = np.mean(shap_values_ori.values, axis=0)
column_mean_xm = np.mean(shap_values_xm.values, axis=0)
column_mean_mi = np.mean(shap_values_mi.values, axis=0)
column_mean_mice = np.mean(shap_values_mice.values, axis=0)
column_mean_dimv = np.mean(shap_values_dimv.values, axis=0)
column_mean_mf = np.mean(shap_values_mf.values, axis=0)
column_mean_soft = np.mean(shap_values_soft.values, axis=0)
heat_df = pd.DataFrame(np.vstack((column_mean_ori, column_mean_xm,column_mean_mi,column_mean_mice,
                                  column_mean_dimv,column_mean_mf,column_mean_soft)))
heat_df.columns = X_train.columns
heat_df.index = np.array(['original', 'XgbM', 'mean imputation', 'MICE','DIMV','missForest', 'SOFT-IMPUTE'])
plt.figure(figsize=(10, 6))
sns.heatmap(heat_df, cmap='viridis', annot=True, cbar=False)
plt.title('Heatmap of shapley average feature mean')
plt.xlabel('Feature')
plt.ylabel('imputation method')
plt.savefig('results/'+ouput_name+'heatmap'+'.png',bbox_inches='tight')
plt.show()
